# %% [markdown]
# # Python codes for [Introduction to Computional Stochastic PDEs, CUP 2014](http://www.cambridge.org/gb/academic/subjects/mathematics/differential-and-integral-equations-dynamical-systems-and-co/introduction-computational-stochastic-pdes?format=PB&isbn=9780521728522)
#
# [T. Shardlow](http://people.bath.ac.uk/tjs42/) Mar 2016
# # Chapter 4

# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
import sys
if sys.version_info < (3,):
    try:
        from builtins import (bytes, dict, int, list, object, range, str,
                              ascii, chr, hex, input, next, oct, open,
                              pow, round, super, filter, map, zip)
        from future.builtins.disabled import (apply, cmp, coerce, execfile,
                                              file, long, raw_input,
                                              reduce, reload,
                                              unicode, xrange, StandardError)
    except:
        print("need future module")

# %%
from math import *
# Numpy
import numpy as np
from numpy import matlib
# Plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# Scipy
import scipy
from scipy import sparse
from scipy.sparse import linalg
from scipy import optimize

# %% [markdown]
# Chapter 4 starts the work with random numbers and the first function shows how to sample from the Gaussian distribution $N(\mu,\sigma)$ and compute the sample mean and variance.

# %%
def est_mean_var_func(mu,sigma,M):
    """
    A4.1 Page 163
    """
    X=np.random.randn(M)
    X=mu + sigma * X
    mu_M=np.mean(X)
    sig_sq_M=np.var(X)
    return mu_M,sig_sq_M

# %%
mu=1;    sigma=1; M=40
mu_M,sig_sq_M=est_mean_var_func(mu,sigma,M)
print("The sample average is", mu_M,
    "and the sample variance", sig_sq_M,
    "based on ", M, "samples for N(1,1)")
# Out:
# The sample average is 0.9856306578551488 and the sample variance 0.9059676348464955 based on  40 samples for N(1,1)

# %% [markdown]
# Python generates pseudo random numbers and the random number stream can be reproduced by storing and resetting the state of the random number generator.

# %%
def setseed0(M):
    """
    A4.2 Page 165
    """
    s0=np.random.RandomState()
    s0_state=s0.get_state()
    r0=s0.randn(M)
    s0.set_state(s0_state)
    r00=s0.randn(M)
    return r0,r00
    
def setseed1(M):
    """
    A4.3 Page 165
    """
    s1=np.random.RandomState()
    s0=np.random.RandomState()
    r1=s1.randn(M)
    r0=s0.randn(M)
    tmp=np.vstack((r1,
                   r0))
    return  np.cov(tmp)

# %% [markdown]
# We show how to reproduce a stream of random numers with `setseet0` and how to work with two uncorrelated random number streams in `setseed1`. Notice that the off-diagonals of the covariance are very small, indicating the samples are uncorrelated.

# %%
r0,r00=setseed0(10)
print("Identical samples:\n",r0,"and\n",r00)
#
print("Covariance of samples", setseed1(1000))
# Out:
# Identical samples:
#  [ 1.33172726  0.6086353  -1.05829099 -1.10132215 -1.39290898  1.59301757
#  -1.08278479  1.17906054  1.76147638  0.43164534] and
#  [ 1.33172726  0.6086353  -1.05829099 -1.10132215 -1.39290898  1.59301757
#  -1.08278479  1.17906054  1.76147638  0.43164534]
# Covariance of samples [[1.07988357 0.00458969]
#  [0.00458969 1.07049393]]

# %% [markdown]
# Let's look now at generating random numbers in parallel.
#
# First, you need to start an ipcluster on your machine. This is done by running `ipcluster start` at the command line (in Windows PowerShell, for example).
#
# The code then sets up N random numbergenerators and stores them in `stream`, and also stores their initial state in `init_state`. First, the code generates N sets of M Gaussians in series, then reproduces one of the rows, and then generates N sets of M Gaussian in parallel.

# %%
from ipyparallel import Client
import os
#
def parseed():
    """
    A4.4 Page 166
    """
    N=4
    M=6
    sr=np.zeros((N,M))
    stream={};    init_state={}
    
    # generate N streams of random numbers
    for j in range(N):
        stream[j]=np.random.RandomState() # create new rng
        init_state[j]=stream[j].get_state() # save initial state
        sr[j,:]=stream[j].randn(1,M)
    
    def srandn(j):# return jth stream of random numbers
        stream[j].set_state(init_state[j])# reset state of jth rng
        return stream[j].randn(1,M)
    #
    sr4=srandn(N-1) # reproduces the 4th row        
    # start ipcluster in terminal
    rc = Client()   
    # wait for 4 engines to be ready
    rc.wait_for_engines(n=4)
    # create a DirectView object
    view = rc[:]
    # tell clients to work in our directory
    view.apply_sync(os.chdir, os.getcwd())
    # distribute the work
    ar=view.map_sync(lambda j: srandn(j),range(N))
    return sr,sr4,ar
#
sr,sr4,ar=parseed()
print("sr=",sr,"\nsr4=",sr4,"ar=\n",ar)
# Out:
#   0%|          | 0/4 [00:00<?, ?engine/s]
# sr= [[ 1.25062661 -0.88363444 -1.34823968  1.71750719  0.3182755   1.8468141 ]
#  [ 0.5027089  -1.0538308   0.54276435 -0.48017682 -0.1524646  -2.45819752]
#  [-0.48164521  0.6022901  -0.78830921 -0.84172857 -0.90713499  0.0466633 ]
#  [-0.46567334  0.97004439 -0.2266412  -0.45448163  0.02138047 -0.11695002]]
# sr4= [[-0.46567334  0.97004439 -0.2266412  -0.45448163  0.02138047 -0.11695002]] ar=
#  [array([[ 1.25062661, -0.88363444, -1.34823968,  1.71750719,  0.3182755 ,
#          1.8468141 ]]), array([[ 0.5027089 , -1.0538308 ,  0.54276435, -0.48017682, -0.1524646 ,
#         -2.45819752]]), array([[-0.48164521,  0.6022901 , -0.78830921, -0.84172857, -0.90713499,
#          0.0466633 ]]), array([[-0.46567334,  0.97004439, -0.2266412 , -0.45448163,  0.02138047,
#         -0.11695002]])]

# %%
def uniform_ball():
    """
    A4.5 Page 167
    """
    theta=np.random.uniform()*2*pi; S=np.random.uniform()
    X=sqrt(S)*np.array([cos(theta),sin(theta)])
    return X

def uniform_sphere():
    """
    A4.6 Page 168
    """
    z=-1+2*np.random.uniform()
    theta=2*pi*np.random.uniform()
    r=sqrt(1-z*z)
    X=np.array([r*cos(theta),r*sin(theta),z])
    return X

def reject_uniform():
    """
    A4.7 Page 168
    """
    M=0; X=np.ones(2);
    while np.linalg.norm(X)>1:# reject
        M=M+1; X=np.random.uniform(-1,1,2) # generate sample
    return X,M

# %% [markdown]
# Here we have sampling methods for the uniform distributions on the ball and the sphere (by change of variables), with an alternative method for generating uniform samples on the unit ball (by rejection sampling)

# %%
print("Uniform sample from unit ball at origin", uniform_ball())
#
print("Uniform sample from unit sphere at origin", uniform_sphere())
#
[X,M]=reject_uniform()
print("Uniform sample of unit ball", X, "using", M, "attempts (rejection sampling)" )
# Out:
# Uniform sample from unit ball at origin [-0.64711253 -0.05675777]
# Uniform sample from unit sphere at origin [ 0.47058454  0.2352381  -0.85041944]
# Uniform sample of unit ball [-0.56596767 -0.81282375] using 2 attempts (rejection sampling)

# %% [markdown]
# Sampling from multivariate Gaussians can be done by the Cholesky factorisation.

# %%
def gauss_chol(mu,C):
    """
    A4.8 Page 170
    """
    R= scipy.linalg.cholesky(C, lower=True)
    Z=np.random.randn(mu.size)
    X=mu+np.dot(R.T,Z)
    return X

# %% [markdown]
# Here's a $2\times 2$ example.

# %%
mu=np.array([0,0])
C=np.array([[2,1],[1,2]])
print("Multivariate Gaussian sample", gauss_chol(mu,C))
# Out:
# Multivariate Gaussian sample [0.11622631 0.30132748]

# %% [markdown]
# We consider an ODE with a random initial data and compute the distribution of one of the components at time $T$, using a simple Monte Carlo method. See Example 4.72.

# %%
import ch3
def pop_monte(M,T,Dt,baru0,epsilon):
    """
    A4.9 Page 174
    """
    d=baru0.size
    N=int(T // Dt)
    u=np.zeros((M,d))  
    for j in range(M):
        u0=baru0 + epsilon * np.random.uniform(-1,1,baru0.size)
        t,usample=ch3.exp_euler(u0,T,N,d,f_pop)
        u[j,:]=usample[:,-1]
    bar_x,sig95=monte(u[:,0])
    return bar_x,sig95
    
def f_pop(u):
    return np.array([u[0]*(1-u[1]),
                     u[1]*(u[0]-1)])

def monte(samples):
    """
    Helper function for A4.9 Page 174
    """
    M=samples.size
    conf95=2 * sqrt(np.var(samples) / M)
    sample_av=np.mean(samples)
    return sample_av,conf95
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import ch3
#       2 def pop_monte(M,T,Dt,baru0,epsilon):
#       3     """
#       4     A4.9 Page 174
#       5     """
#
# File c:\Users\tonys\Documents\GitHub\PICSPDE\ch3.py:60
#      56     return scipy.fftpack.dst(u,type=1,axis=0)/2
#      59 #
# ---> 60 import ch0
#      61 import ch2
#      62 #
#
# File c:\Users\tonys\Documents\GitHub\PICSPDE\ch0.py:21
#      16 from __future__ import (absolute_import, division,
#      17                         print_function, unicode_literals)
#      18 from builtins import (bytes, dict, int, list, object, range, str,
#      19                       ascii, chr, hex, input, next, oct, open,
#      20                       pow, round, super, filter, map, zip)
# ---> 21 from future.builtins.disabled import (apply, cmp, coerce, execfile,
#      22                                       file, long, raw_input, reduce, reload,
#      23                                       unicode, xrange, StandardError)
#      24 #
#      25 import sys
#
# ModuleNotFoundError: No module named 'future'

# %%
M=4*int(1e2); T=6
Dt=2e-3
baru0=np.array([0.5,2])
epsilon=0.2
bar_x,sig95=pop_monte(M,T,Dt,baru0,epsilon)
print("mean",bar_x,"sd",sig95)

# %% [markdown]
# By introducing a symmetry to the samples of the initial data, we reduce the variance in the quantity of interest.

# %%
def pop_monte_anti(M,T,Dt,baru0,epsilon):
    d=baru0.size
    N=int(T // Dt)
    u=np.zeros((2*M,d))  
    for j in range(M):
        u0=baru0 + epsilon * np.random.uniform(-1,1,baru0.size)
        t,usample=ch3.exp_euler(u0,T,N,d,f_pop)
        u[j,:]=usample[:,-1]
        u0=2 * baru0 - u0
        t,usample=ch3.exp_euler(u0,T,N,d,f_pop)
        u[j+M,:]=usample[:,-1]
    bar_x,sig95=monte(u[:,0])
    return bar_x,sig95

# %% [markdown]
# The resuling mean is similar, but the standard deviation is slightly reduced. Both runs are based on the same number of samples.

# %%
M=2*int(1e2); T=6
Dt=2e-3
baru0=np.array([0.5,2]); epsilon=0.2
bar_x,sig95=pop_monte_anti(M,T,Dt,baru0,epsilon)
print("mean",bar_x,"sd",sig95)
